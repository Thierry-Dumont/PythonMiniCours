# %% [markdown]
# # Bibliothèques (en C, C++ ou autre langage) interfacées avec Python
#
# - PyOpenCv : interface avec OpenCv (traitement d'images, reconnaissance automatique)
# - PyQt
# - PyPandoc
# - et _des centaines d'autres !_
#
# sur Raspberry, les ports GPIO sont accessibles  en Python...

# %% [markdown]
# # Quelques logiciels
#
# ### qui mélangent Python avec des parties écrites dans d'autres langages (C, C++,...).
#
# En général, les _superstructures_ sont en Python, et les parties intensives en C, C++, etc.

# %% [markdown]
# * ### Apprentissage profond (deep learning):
#
#  - Pytorch (origine : Meta)
#  - Tensorflow (origine : Google)
#
#  _Attention, ces logiciels sont libres, mais ils demandent un GPU Nvidia et la bibliothèque Cuda (pas libre !) pour faire autre choses que des applications "jeux"._

# %% [markdown]
# ### Science, calcul...
#
# * SageMath : logiciel de mathématiques. Les superstructures sont en Python, chef d'œuvre de Nicolas Thiery (ISIL),
# un des fondateurs de l'ALDIL, souvent venu aux JDLL.

# %% [markdown]
# * Code-Aster : calcul de structures (EDF). Développement commencé il y a plus de 40 ans (Fortran): langage de commande Python.
#
# ![confluences.png](attachment:confluences.png)

# %% [markdown]
# ### Web...
# * Django : sites web, modèle MVC.

# %% [markdown]
# ## Jupyter

# %% [markdown]
# [JUlia, PYthon, R](https://jupyter.org/)

# %% [markdown]
# ### Rejouer tout ça ?
#
# #### Tout est sur [Github](https://github.com/Thierry-Dumont/PythonMiniCours)
#
#
# https://github.com/Thierry-Dumont/PythonMiniCours
